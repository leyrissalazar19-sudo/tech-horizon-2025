# %%
pelicula = {
    "Titulo": "La sirenita",
    "director": "Rob  marshall",
    "año": 2023,
    "genero": "Fantasia" , "Musical"
    "calificacion": 10,
    "actores principales": ["halley bailey", "melissa mcCarty" , "jonah hauer-King"]
}

for clave, valor in pelicula.items():
  print("=== imformacion de la pelicula ===")
# Out:
# === imformacion de la pelicula ===
# === imformacion de la pelicula ===
# === imformacion de la pelicula ===
# === imformacion de la pelicula ===
# === imformacion de la pelicula ===
# === imformacion de la pelicula ===
